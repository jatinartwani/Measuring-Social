# %%
import pandas as pd
from scipy.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/Users/jatinartwani/Documents/Personal/CMU/MISM/Sem2/Measuring Social/Barbie/barbie-chart_data-volume-days-pageTypes.csv")

# %%
df
# Out:
#                 days  07/21/2023  07/22/2023  07/23/2023  07/24/2023  \
# 0        Online News        3727        1757        1776        3394
# 1                 QQ           0           0           0           0
# 2            YouTube          98         108          96          99
# 3          Broadcast           0           0           0           0
# 4           Facebook           0           0           0           4
# 5   Legacy Instagram           0           0           0           0
# 6             Tumblr        4349        6020        6746        6423
# 7          Instagram           1           0           1           0
# 8           LinkedIn           0           0           0           0
# 9              Blogs         235         114         150         211
# 10            Forums         320         452         592         399
# 11   Facebook Public         210          72          56         101
# 12                 X       14482       24852       15922        7442
# 13                VK           0           0           0           0
# 14            Review          24          28          16          24
# 15            Reddit         875        1356        1662        1499
# 16             4Chan           0           0           0           0
#
#     07/25/2023  07/26/2023  07/27/2023  07/28/2023  07/29/2023  ...  \
# 0         2417        1814        1705        1819         878  ...
# 1            0           0           0           0           0  ...
# 2          114          93          93          64          87  ...
# 3            0           0           0           0           0  ...
# 4            1           0           0           0           0  ...
# 5            0           0           0           0           0  ...
# 6         8398        6104        6889        5581        4482  ...
# 7            0           0           0           1           0  ...
# 8            0           0           0           0           0  ...
# 9          169         142         111         102          69  ...
# 10         259         229         180         186         143  ...
# 11          73          69          45          43          21  ...
# 12        4258        2951        2101        1823        1816  ...
# 13           0           0           0           0           0  ...
# 14          24          14          35          12          38  ...
# 15        1647        1434        1315        1146         591  ...
# 16           0           0           0           0           0  ...
#
#     01/12/2024  01/13/2024  01/14/2024  01/15/2024  01/16/2024  01/17/2024  \
# 0          848         522        1521        2107         756        1264
# 1            0           0           0           0           0           0
# 2            7           7           5           7           4          21
# 3            0           0           0           0           0           0
# 4            0           0           0           0           0           0
# 5            0           0           0           0           0           0
# 6          229         159         394         295         232         181
# 7            0           0           0           1           1           0
# 8            0           0           0           0           0           0
# 9           29          25          18          35          23          20
# 10          20          16          19          36          22          18
# 11           3           2           5          11           3           2
# 12         120         158         372         206         111         231
# 13           0           0           0           0           0           0
# 14           5           5           3           1           1           0
# 15          53          53          79          66          35          83
# 16           0           0           0           0           0           0
#
#     01/18/2024  01/19/2024  01/20/2024  01/21/2024
# 0         1992         636         367         834
# 1            0           0           0           0
# 2           16          10           1          12
# 3            0           0           0           0
# 4            0           0           0           0
# 5            0           0           0           0
# 6          147         177         256         337
# 7            0           1           0           1
# 8            0           0           0           0
# 9           27          26          10          16
# 10          28          22          12          24
# 11          13          12           3           2
# 12         588         189          93          91
# 13           0           0           0           0
# 14           1           1           3           3
# 15         299         103          54          54
# 16           0           0           0           0
#
# [17 rows x 186 columns]

# %%
engagement = df.copy()

# %%
#Transpose Matrix
engagement = engagement.transpose()

# %%
#Creating df for Regression Analysis
reg_engagement = df.transpose().copy()

# %%
#Calculate Sum of engagements from each source
row_sums = engagement.sum(axis=1)

# Add row sums as a new column
engagement['total'] = row_sums
#engagement['total'] = engagement.iloc[:,6] #Only Forums

#Drop first Row containing all sources
engagement = engagement.drop(engagement.index[0])

#Drop all columns except the 'total' column
columns_to_keep = [engagement.columns[-1]]
engagement = engagement[columns_to_keep]

engagement.index.name = 'date'
engagement.index = pd.to_datetime(engagement.index)

# %%
engagement
# Out:
#             total
# date
# 2023-07-21  24321
# 2023-07-22  34759
# 2023-07-23  27017
# 2023-07-24  19596
# 2023-07-25  17360
# ...           ...
# 2024-01-17   1820
# 2024-01-18   3111
# 2024-01-19   1177
# 2024-01-20    799
# 2024-01-21   1374
#
# [185 rows x 1 columns]

# %%
bo = pd.read_csv("/Users/jatinartwani/Documents/Personal/CMU/MISM/Sem2/Measuring Social/Iron Claw/ironclaw-bo.csv")

# %%
bo = bo.dropna(axis=1)

# %%
bo
# Out:
#           date     revenue      to_date
# 0   12/22/2023  $2,496,600   $2,496,600
# 1   12/23/2023  $1,553,440   $4,050,040
# 2   12/24/2023    $818,330   $4,868,370
# 3   12/25/2023  $1,930,705   $6,799,075
# 4   12/26/2023  $1,708,784   $8,507,859
# ..         ...         ...          ...
# 61  02/21/2024     $10,561  $35,018,354
# 62  02/22/2024      $8,275  $35,026,629
# 63  02/23/2024     $12,765  $35,039,394
# 64  02/24/2024     $17,616  $35,057,010
# 65  02/25/2024     $13,212  $35,070,222
#
# [66 rows x 3 columns]

# %%
#Fixing 'date' column
#bo['date'] = pd.to_datetime(bo['date'] + '-2021', format='%b-%d-%Y')

#bo['date'] = bo['date'].dt.strftime('%m/%d/%Y')

# Making 'date' the index of the DataFrame
bo.set_index('date', inplace=True)

#Remove $ value
bo['revenue'] = bo['revenue'].str.replace('$', '')
bo['revenue'] = bo['revenue'].str.replace(',', '')

# %%
bo
# Out:
#             revenue      to_date
# date
# 12/22/2023  2496600   $2,496,600
# 12/23/2023  1553440   $4,050,040
# 12/24/2023   818330   $4,868,370
# 12/25/2023  1930705   $6,799,075
# 12/26/2023  1708784   $8,507,859
# ...             ...          ...
# 02/21/2024    10561  $35,018,354
# 02/22/2024     8275  $35,026,629
# 02/23/2024    12765  $35,039,394
# 02/24/2024    17616  $35,057,010
# 02/25/2024    13212  $35,070,222
#
# [66 rows x 2 columns]

# %%
engagement['total'] = pd.to_numeric(engagement['total'], errors='coerce')
bo['revenue'] = pd.to_numeric(bo['revenue'], errors='coerce')

# %%
engagement_ts = engagement.copy()
bo_ts = bo.copy()

# %%
engagement_ts
# Out:
#             total
# date
# 2023-12-22   1778
# 2023-12-23   1895
# 2023-12-24   1172
# 2023-12-25    870
# 2023-12-26   1233
# ...           ...
# 2024-02-21    203
# 2024-02-22    205
# 2024-02-23    174
# 2024-02-24    179
# 2024-02-25    271
#
# [66 rows x 1 columns]

# %%
bo_ts.head(45)
# Out:
#             revenue      to_date
# date
# 12/22/2023  2496600   $2,496,600
# 12/23/2023  1553440   $4,050,040
# 12/24/2023   818330   $4,868,370
# 12/25/2023  1930705   $6,799,075
# 12/26/2023  1708784   $8,507,859
# 12/27/2023  1409192   $9,917,051
# 12/28/2023  1398096  $11,315,147
# 12/29/2023  1704340  $13,019,487
# 12/30/2023  1908861  $14,928,348
# 12/31/2023  1036574  $15,964,922
# 01/01/2024  1388618  $17,353,540
# 01/02/2024   933196  $18,286,736
# 01/03/2024   757174  $19,043,910
# 01/04/2024   771144  $19,815,054
# 01/05/2024  1320085  $21,135,139
# 01/06/2024  1861320  $22,996,459
# 01/07/2024  1340150  $24,336,609
# 01/08/2024   401384  $24,737,993
# 01/09/2024   603321  $25,341,314
# 01/10/2024   501235  $25,842,549
# 01/11/2024   392611  $26,235,160
# 01/12/2024   690905  $26,926,065
# 01/13/2024   949985  $27,876,050
# 01/14/2024   759988  $28,636,038
# 01/15/2024   492334  $29,128,372
# 01/16/2024   301965  $29,430,337
# 01/17/2024   267894  $29,698,231
# 01/18/2024   225412  $29,923,643
# 01/19/2024   501255  $30,424,898
# 01/20/2024   641606  $31,066,504
# 01/21/2024   403443  $31,469,947
# 01/22/2024   155764  $31,625,711
# 01/23/2024   221309  $31,847,020
# 01/24/2024   163211  $32,010,231
# 01/25/2024   159885  $32,170,116
# 01/26/2024   308358  $32,478,474
# 01/27/2024   459444  $32,937,918
# 01/28/2024   206785  $33,144,703
# 01/29/2024    91246  $33,235,949
# 01/30/2024   138963  $33,374,912
# 01/31/2024    89094  $33,464,006
# 02/01/2024    87512  $33,551,518
# 02/02/2024   166742  $33,718,260
# 02/03/2024   274522  $33,992,782
# 02/04/2024   200401  $34,193,183

# %%
# Combine your datasets into a single DataFrame 
combined_df = pd.concat([engagement_ts['total'], bo_ts['revenue']], axis=1)
combined_df.columns = ['total', 'revenue']

# %%
combined_df.head(66)
# Out:
#             total  revenue
# date
# 2023-12-22   1778  2496600
# 2023-12-23   1895  1553440
# 2023-12-24   1172   818330
# 2023-12-25    870  1930705
# 2023-12-26   1233  1708784
# ...           ...      ...
# 2024-02-21    203    10561
# 2024-02-22    205     8275
# 2024-02-23    174    12765
# 2024-02-24    179    17616
# 2024-02-25    271    13212
#
# [66 rows x 2 columns]

# %%
#Making Data Stationary

#Differencing
#engagement_ts['total'] = engagement_ts['total'].diff()
#bo_ts['revenue'] = bo_ts['revenue'].diff()


#Taking Logarithm
#engagement_ts['total'] = np.log(engagement_ts['total'])
#bo_ts['revenue'] = bo_ts['revenue'].replace(-np.inf, np.nan)

# Dropping NA values after making it stationary
#engagement_ts.dropna(inplace=True)
#bo_ts.dropna(inplace=True)

# %%
#Checking Stationarity
from statsmodels.tsa.stattools import adfuller

def check_stationarity(series):
    result = adfuller(series, autolag='AIC')
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# Example usage
check_stationarity(engagement_ts['total'])
check_stationarity(bo_ts['revenue'])
# Out:
# ADF Statistic: -3.835672
# p-value: 0.002563
# Critical Values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ADF Statistic: -4.932943
# p-value: 0.000030
# Critical Values:
# 	1%: -3.553
# 	5%: -2.915
# 	10%: -2.595

# %%
fig, ax1 = plt.subplots(figsize=(20,10))

color = 'tab:blue'
ax1.set_xlabel('Timeline',fontsize=12,fontweight='bold')
ax1.set_ylabel('Social Media Engagement',color=color,fontsize=12,fontweight='bold')
ax1.plot(combined_df.index,combined_df['total'],color=color)
ax1.tick_params(axis='y',labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Revenue $',color=color,fontsize=12,fontweight='bold')
ax2.plot(combined_df.index, combined_df['revenue'],color=color)
ax2.tick_params(axis='y',labelcolor=color)

y_labels = ['{:,.0f}'.format(y) for y in plt.gca().get_yticks()]
plt.gca().set_yticklabels(y_labels)
plt.title('Priscilla: Social Media Engagement vs Box Office Revenue (115 days)',fontsize=12,fontweight='bold')

plt.grid(False)
plt.show()

# %%
correlation, _ = pearsonr(combined_df['total'], combined_df['revenue'])

# %%
print(f'Pearson correlation coefficient: {correlation}')
# Out:
# Pearson correlation coefficient: 0.6441415934272716

# %%
def cross_correlation(series1, series2, lag=0):
    return series1.corr(series2.shift(lag))

# Example usage:
lags = range(0, 7)  # Example lag values from 0 to 12
cross_corr_values = {}
for lag in lags:
    cross_corr_values[lag] = cross_correlation(combined_df['total'], combined_df['revenue'], lag)


max_pair = max(cross_corr_values.items(), key=lambda x: x[1])

#print(cross_corr_values.values())
#cross_corr_values = [cross_correlation(combined_df['total'], combined_df['revenue'], lag) for lag in lags]

print(f'Maximum Pearson correlation coefficient: {max_pair[1]}')
print(f'Lag associated with Maximum Pearson correlation coefficient: {max_pair[0]}')
# Plotting the cross-correlation values
import matplotlib
#matplotlib.use('TkAgg')  # Use TkAgg backend
import matplotlib.pyplot as plt

plt.figure(figsize=(24, 12))
plt.stem(lags, cross_corr_values.values(), use_line_collection=True)
plt.xlabel('Lag (Days)',fontsize=16,fontweight='bold')
plt.ylabel('Cross-correlation',fontsize=16,fontweight='bold',labelpad=20)
plt.title('Cross-correlation between Social Media Engagement and Box Office Revenue',fontsize=18,fontweight='bold')
plt.show()
# Out:
# Maximum Pearson correlation coefficient: 0.6724050894239602
# Lag associated with Maximum Pearson correlation coefficient: 1

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests

# Combine your datasets into a single DataFrame for the Granger causality test
combined_df = pd.concat([engagement_ts['total'], bo_ts['revenue']], axis=1)
combined_df.columns = ['total', 'revenue']

# Perform the Granger causality test
# The maxlag parameter is the maximum lag to test for, and the test 'ssr_chi2test' is one of the possible tests
granger_test_results = grangercausalitytests(combined_df, maxlag=10, verbose=True)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=11.5851 , p=0.0012  , df_denom=62, df_num=1
# ssr based chi2 test:   chi2=12.1457 , p=0.0005  , df=1
# likelihood ratio test: chi2=11.1350 , p=0.0008  , df=1
# parameter F test:         F=11.5851 , p=0.0012  , df_denom=62, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2262  , p=0.0468  , df_denom=59, df_num=2
# ssr based chi2 test:   chi2=6.9993  , p=0.0302  , df=2
# likelihood ratio test: chi2=6.6424  , p=0.0361  , df=2
# parameter F test:         F=3.2262  , p=0.0468  , df_denom=59, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9011  , p=0.1399  , df_denom=56, df_num=3
# ssr based chi2 test:   chi2=6.4161  , p=0.0930  , df=3
# likelihood ratio test: chi2=6.1100  , p=0.1064  , df=3
# parameter F test:         F=1.9011  , p=0.1399  , df_denom=56, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4836  , p=0.0546  , df_denom=53, df_num=4
# ssr based chi2 test:   chi2=11.6214 , p=0.0204  , df=4
# likelihood ratio test: chi2=10.6517 , p=0.0308  , df=4
# parameter F test:         F=2.4836  , p=0.0546  , df_denom=53, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0580  , p=0.0864  , df_denom=50, df_num=5
# ssr based chi2 test:   chi2=12.5537 , p=0.0279  , df=5
# likelihood ratio test: chi2=11.4156 , p=0.0437  , df=5
# parameter F test:         F=2.0580  , p=0.0864  , df_denom=50, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3916  , p=0.0425  , df_denom=47, df_num=6
# ssr based chi2 test:   chi2=18.3183 , p=0.0055  , df=6
# likelihood ratio test: chi2=15.9862 , p=0.0138  , df=6
# parameter F test:         F=2.3916  , p=0.0425  , df_denom=47, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4411  , p=0.2136  , df_denom=44, df_num=7
# ssr based chi2 test:   chi2=13.5268 , p=0.0603  , df=7
# likelihood ratio test: chi2=12.1787 , p=0.0948  , df=7
# parameter F test:         F=1.4411  , p=0.2136  , df_denom=44, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2090  , p=0.3179  , df_denom=41, df_num=8
# ssr based chi2 test:   chi2=13.6823 , p=0.0904  , df=8
# likelihood ratio test: chi2=12.2845 , p=0.1390  , df=8
# parameter F test:         F=1.2090  , p=0.3179  , df_denom=41, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0845  , p=0.3964  , df_denom=38, df_num=9
# ssr based chi2 test:   chi2=14.6410 , p=0.1013  , df=9
# likelihood ratio test: chi2=13.0312 , p=0.1612  , df=9
# parameter F test:         F=1.0845  , p=0.3964  , df_denom=38, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4989  , p=0.8790  , df_denom=35, df_num=10
# ssr based chi2 test:   chi2=7.9831  , p=0.6305  , df=10
# likelihood ratio test: chi2=7.4630  , p=0.6811  , df=10
# parameter F test:         F=0.4989  , p=0.8790  , df_denom=35, df_num=10

# %%
#Linear Regression Fit
reg_engagement
# Out:
#                       0   1        2          3         4                 5  \
# days        Online News  QQ  YouTube  Broadcast  Facebook  Legacy Instagram
# 12/22/2023          612   0        5          0         0                 0
# 12/23/2023          387   0        6          0         0                 0
# 12/24/2023          243   0        6          0         0                 0
# 12/25/2023          168   0        1          0         0                 0
# ...                 ...  ..      ...        ...       ...               ...
# 02/21/2024           90   0        0          0         0                 0
# 02/22/2024           86   0        0          0         0                 0
# 02/23/2024           18   0        0          0         0                 0
# 02/24/2024           47   0        1          0         0                 0
# 02/25/2024          122   0        0          0         0                 0
#
#                  6          7         8      9      10               11    12  \
# days        Tumblr  Instagram  LinkedIn  Blogs  Forums  Facebook Public     X
# 12/22/2023       8          0         0     23      20               14  1001
# 12/23/2023      11          0         0     13      33               52  1257
# 12/24/2023      10          1         0     10      25                3   787
# 12/25/2023       9          0         0     13      14                1   539
# ...            ...        ...       ...    ...     ...              ...   ...
# 02/21/2024      19          0         0      3       4                0    72
# 02/22/2024      19          0         0      2       9                0    63
# 02/23/2024      19          0         0      4       7                0   108
# 02/24/2024      30          0         0      2       4                0    66
# 02/25/2024      15          0         0      4      19                0    88
#
#             13      14      15                16     17
# days        VK  Review  Reddit  TvEyes Broadcast  4Chan
# 12/22/2023   0       4      91                 0      0
# 12/23/2023   0       3     133                 0      0
# 12/24/2023   0       0      87                 0      0
# 12/25/2023   0       0     125                 0      0
# ...         ..     ...     ...               ...    ...
# 02/21/2024   0       1      14                 0      0
# 02/22/2024   0       0      26                 0      0
# 02/23/2024   0       0      18                 0      0
# 02/24/2024   0       0      29                 0      0
# 02/25/2024   0       0      23                 0      0
#
# [67 rows x 18 columns]

# %%
#Make first row as Columns
reg_engagement.columns = reg_engagement.iloc[0]

# %%
#Drop first row
reg_engagement = reg_engagement.drop(reg_engagement.index[0])

# %%
#Drop Columns (Content Sources where all values are 0)
reg_engagement = reg_engagement.loc[:, (reg_engagement != 0).any(axis=0)]

# %%
reg_engagement = reg_engagement.rename(columns={'days': 'date'})

# %%
reg_engagement
# Out:
# days       Online News YouTube Facebook Tumblr Instagram Blogs Forums  \
# 12/22/2023         612       5        0      8         0    23     20
# 12/23/2023         387       6        0     11         0    13     33
# 12/24/2023         243       6        0     10         1    10     25
# 12/25/2023         168       1        0      9         0    13     14
# 12/26/2023         123      11        0     32         0     8     18
# ...                ...     ...      ...    ...       ...   ...    ...
# 02/21/2024          90       0        0     19         0     3      4
# 02/22/2024          86       0        0     19         0     2      9
# 02/23/2024          18       0        0     19         0     4      7
# 02/24/2024          47       1        0     30         0     2      4
# 02/25/2024         122       0        0     15         0     4     19
#
# days       Facebook Public     X Review Reddit
# 12/22/2023              14  1001      4     91
# 12/23/2023              52  1257      3    133
# 12/24/2023               3   787      0     87
# 12/25/2023               1   539      0    125
# 12/26/2023               1   922      1    117
# ...                    ...   ...    ...    ...
# 02/21/2024               0    72      1     14
# 02/22/2024               0    63      0     26
# 02/23/2024               0   108      0     18
# 02/24/2024               0    66      0     29
# 02/25/2024               0    88      0     23
#
# [66 rows x 11 columns]

# %%
shift = -1 #Based on Lag

# %%
bo_series = bo['revenue']

# %%
bo_series
# Out:
# date
# 12/22/2023    2496600
# 12/23/2023    1553440
# 12/24/2023     818330
# 12/25/2023    1930705
# 12/26/2023    1708784
#                ...
# 02/21/2024      10561
# 02/22/2024       8275
# 02/23/2024      12765
# 02/24/2024      17616
# 02/25/2024      13212
# Name: revenue, Length: 66, dtype: int64

# %%
bo_series_shifted = bo_series.shift(shift)

# %%
bo_series_shifted = bo_series_shifted[:shift]

# %%
bo_series_shifted
# Out:
# date
# 12/22/2023    1553440.0
# 12/23/2023     818330.0
# 12/24/2023    1930705.0
# 12/25/2023    1708784.0
# 12/26/2023    1409192.0
#                 ...
# 02/20/2024      10561.0
# 02/21/2024       8275.0
# 02/22/2024      12765.0
# 02/23/2024      17616.0
# 02/24/2024      13212.0
# Name: revenue, Length: 65, dtype: float64

# %%
reg_engagement = reg_engagement.iloc[:shift, :]

# %%
reg_engagement
# Out:
# days       Online News YouTube Facebook Tumblr Instagram Blogs Forums  \
# 12/22/2023         612       5        0      8         0    23     20
# 12/23/2023         387       6        0     11         0    13     33
# 12/24/2023         243       6        0     10         1    10     25
# 12/25/2023         168       1        0      9         0    13     14
# 12/26/2023         123      11        0     32         0     8     18
# ...                ...     ...      ...    ...       ...   ...    ...
# 02/20/2024          35       1        0     31         0     0     17
# 02/21/2024          90       0        0     19         0     3      4
# 02/22/2024          86       0        0     19         0     2      9
# 02/23/2024          18       0        0     19         0     4      7
# 02/24/2024          47       1        0     30         0     2      4
#
# days       Facebook Public     X Review Reddit
# 12/22/2023              14  1001      4     91
# 12/23/2023              52  1257      3    133
# 12/24/2023               3   787      0     87
# 12/25/2023               1   539      0    125
# 12/26/2023               1   922      1    117
# ...                    ...   ...    ...    ...
# 02/20/2024               0   114      1     35
# 02/21/2024               0    72      1     14
# 02/22/2024               0    63      0     26
# 02/23/2024               0   108      0     18
# 02/24/2024               0    66      0     29
#
# [65 rows x 11 columns]

# %%
reg_engagement = reg_engagement.astype(int)

# %%
reg_engagement
# Out:
# days        Online News  YouTube  Facebook  Tumblr  Instagram  Blogs  Forums  \
# 12/22/2023          612        5         0       8          0     23      20
# 12/23/2023          387        6         0      11          0     13      33
# 12/24/2023          243        6         0      10          1     10      25
# 12/25/2023          168        1         0       9          0     13      14
# 12/26/2023          123       11         0      32          0      8      18
# ...                 ...      ...       ...     ...        ...    ...     ...
# 02/20/2024           35        1         0      31          0      0      17
# 02/21/2024           90        0         0      19          0      3       4
# 02/22/2024           86        0         0      19          0      2       9
# 02/23/2024           18        0         0      19          0      4       7
# 02/24/2024           47        1         0      30          0      2       4
#
# days        Facebook Public     X  Review  Reddit
# 12/22/2023               14  1001       4      91
# 12/23/2023               52  1257       3     133
# 12/24/2023                3   787       0      87
# 12/25/2023                1   539       0     125
# 12/26/2023                1   922       1     117
# ...                     ...   ...     ...     ...
# 02/20/2024                0   114       1      35
# 02/21/2024                0    72       1      14
# 02/22/2024                0    63       0      26
# 02/23/2024                0   108       0      18
# 02/24/2024                0    66       0      29
#
# [65 rows x 11 columns]

# %%
bo_series_shifted
# Out:
# date
# 12/22/2023    1553440.0
# 12/23/2023     818330.0
# 12/24/2023    1930705.0
# 12/25/2023    1708784.0
# 12/26/2023    1409192.0
#                 ...
# 02/20/2024      10561.0
# 02/21/2024       8275.0
# 02/22/2024      12765.0
# 02/23/2024      17616.0
# 02/24/2024      13212.0
# Name: revenue, Length: 65, dtype: float64

# %%
# Prepare the features (X) and the target (y)
X = reg_engagement  # 'Reg Engagement' df as features
y = bo_series_shifted  # 'Revenue' series

# Reset index if necessary
X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Add a constant to the model (for the intercept)
X_scaled_with_const = sm.add_constant(X_scaled)

# Fit the OLS model
model = sm.OLS(y, X_scaled_with_const).fit()

# Get the regression report
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     7.499
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           1.42e-07
# Time:                        15:41:33   Log-Likelihood:                -922.75
# No. Observations:                  65   AIC:                             1869.
# Df Residuals:                      53   BIC:                             1896.
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            5.011e+05   4.86e+04     10.305      0.000    4.04e+05    5.99e+05
# Online News      8.727e+04   7.38e+04      1.182      0.242   -6.08e+04    2.35e+05
# YouTube         -8648.5338   8.09e+04     -0.107      0.915   -1.71e+05    1.54e+05
# Facebook          2.36e+04   5.01e+04      0.471      0.640    -7.7e+04    1.24e+05
# Tumblr          -1.335e+05    5.6e+04     -2.385      0.021   -2.46e+05   -2.12e+04
# Instagram        5.854e+04   4.93e+04      1.187      0.241   -4.04e+04    1.57e+05
# Blogs            1.614e+05   9.04e+04      1.785      0.080      -2e+04    3.43e+05
# Forums          -2305.3425   5.23e+04     -0.044      0.965   -1.07e+05    1.03e+05
# Facebook Public -1.109e+05   6.13e+04     -1.807      0.076   -2.34e+05    1.22e+04
# X                1.153e+05    1.1e+05      1.044      0.301   -1.06e+05    3.37e+05
# Review           9.944e+04   6.25e+04      1.590      0.118    -2.6e+04    2.25e+05
# Reddit           1.392e+05   7.72e+04      1.804      0.077   -1.56e+04    2.94e+05
# ==============================================================================
# Omnibus:                       13.285   Durbin-Watson:                   0.991
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               39.582
# Skew:                           0.346   Prob(JB):                     2.54e-09
# Kurtosis:                       6.760   Cond. No.                         5.58
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
# Extract the coefficients (excluding the intercept) and sort them by their absolute values
coefficients = model.params.drop('const').abs().sort_values(ascending=False)

# Print the sorted coefficients to identify the top contributing features
print("\nTop Contributing Features:")
print(coefficients)
# Out:
# Top Contributing Features:
# X                  165826.059976
# Blogs              112403.254722
# YouTube             80756.352701
# Tumblr              64818.784861
# Instagram           58670.775376
# Reddit              53362.565346
# Online News         51209.973192
# Review              24479.079727
# Facebook Public     17502.231702
# Forums                452.894909
# dtype: float64
