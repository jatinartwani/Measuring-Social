# %%
import pandas as pd
from scipy.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/Users/jatinartwani/Documents/Personal/CMU/MISM/Sem2/Measuring Social/Oppenheimer/oppenheimer-chart_data-volume-days-pageTypes.csv")

# %%
df
# Out:
#                 days  07/21/2023  07/22/2023  07/23/2023  07/24/2023  \
# 0        Online News        2002        1342        1635        2554
# 1                 QQ           0           0           0           0
# 2            YouTube          68          53          44          53
# 3          Broadcast           0           0           0           0
# 4           Facebook           0           0           0           1
# 5   Legacy Instagram           0           0           0           0
# 6             Tumblr         462        1336        1607         740
# 7          Instagram           0           0           0           0
# 8           LinkedIn           0           0           0           0
# 9              Blogs         134          70          85         132
# 10            Forums         246         375         303         326
# 11   Facebook Public          60          33          25          45
# 12                 X        5901       10527        6001        4472
# 13                VK           0           0           0           0
# 14            Review          19          11           4           8
# 15            Reddit         802         900         953         889
# 16             4Chan           0           0           0           0
#
#     07/25/2023  07/26/2023  07/27/2023  07/28/2023  07/29/2023  ...  \
# 0         1438         945         786         778         648  ...
# 1            0           0           0           0           0  ...
# 2           45          21          22          28          25  ...
# 3            0           0           0           0           0  ...
# 4            0           0           0           0           0  ...
# 5            0           0           0           0           0  ...
# 6          915         416         332         344         267  ...
# 7            0           0           0           0           0  ...
# 8            0           0           0           0           0  ...
# 9           80          67          66          66          44  ...
# 10         207         135         219         127         135  ...
# 11          14          19          18          15           7  ...
# 12        1700        1114         874         890         885  ...
# 13           0           0           0           0           0  ...
# 14           6           5           3           5           1  ...
# 15         761         467         368         452         327  ...
# 16           0           0           0           0           0  ...
#
#     03/12/2024  03/13/2024  03/14/2024  03/15/2024  03/16/2024  03/17/2024  \
# 0         2591         841         649         315         222         179
# 1            0           0           0           0           0           0
# 2            5           4           2           4           4           2
# 3            0           0           0           0           0           0
# 4            0           0           0           0           0           0
# 5            0           0           0           0           0           0
# 6           26           8           7          10           3           4
# 7            0           0           0           0           0           0
# 8            0           0           0           0           0           0
# 9           34          22          13          24          13          10
# 10          73          33          18          15          15          12
# 11          32          12           6           6           0           2
# 12        1403         459         179         135         191         262
# 13           0           0           0           0           0           0
# 14           0           2           3           5           4           2
# 15         218          73         102         114          70         210
# 16           0           0           0           0           0           0
#
#     03/18/2024  03/19/2024  03/20/2024  03/21/2024
# 0          361         266         176         502
# 1            0           0           0           0
# 2            1           2           2           1
# 3            0           0           0           0
# 4            0           0           0           0
# 5            0           0           0           0
# 6            7           2           2           3
# 7            0           0           0           0
# 8            0           0           0           0
# 9           10           4          10           4
# 10          19          24           9           7
# 11           2           2           2           0
# 12          59          57         196         133
# 13           0           0           0           0
# 14           1           1           2           5
# 15         172         116          92          77
# 16           0           0           0           0
#
# [17 rows x 246 columns]

# %%
engagement = df.copy()

# %%
#Transpose Matrix
engagement = engagement.transpose()

# %%
#Creating df for Regression Analysis
reg_engagement = df.transpose().copy()

# %%
#Calculate Sum of engagements from each source
row_sums = engagement.sum(axis=1)

# Add row sums as a new column
engagement['total'] = row_sums
#engagement['total'] = engagement.iloc[:,6] #Only Forums

#Drop first Row containing all sources
engagement = engagement.drop(engagement.index[0])

#Drop all columns except the 'total' column
columns_to_keep = [engagement.columns[-1]]
engagement = engagement[columns_to_keep]

engagement.index.name = 'date'
engagement.index = pd.to_datetime(engagement.index)

# %%
engagement
# Out:
#             total
# date
# 2023-07-21   9694
# 2023-07-22  14647
# 2023-07-23  10657
# 2023-07-24   9220
# 2023-07-25   5166
# ...           ...
# 2024-03-17    683
# 2024-03-18    632
# 2024-03-19    474
# 2024-03-20    491
# 2024-03-21    732
#
# [245 rows x 1 columns]

# %%
bo = pd.read_csv("/Users/jatinartwani/Documents/Personal/CMU/MISM/Sem2/Measuring Social/Oppenheimer/oppenheimer-bo.csv")

# %%
bo = bo.dropna(axis=1)

# %%
bo
# Out:
#            date      revenue       to_date
# 0    07/21/2023  $33,017,635   $33,017,635
# 1    07/22/2023  $26,248,140   $59,265,775
# 2    07/23/2023  $23,189,645   $82,455,420
# 3    07/24/2023  $12,671,950   $95,127,370
# 4    07/25/2023  $12,073,530  $107,200,900
# ..          ...          ...           ...
# 240  03/17/2024      $83,460  $329,702,240
# 241  03/18/2024      $38,620  $329,740,860
# 242  03/19/2024      $55,355  $329,796,215
# 243  03/20/2024      $39,005  $329,835,220
# 244  03/21/2024      $27,320  $329,862,540
#
# [245 rows x 3 columns]

# %%
#Fixing 'date' column
#bo['date'] = pd.to_datetime(bo['date'] + '-2021', format='%b-%d-%Y')

#bo['date'] = bo['date'].dt.strftime('%m/%d/%Y')

# Making 'date' the index of the DataFrame
bo.set_index('date', inplace=True)

#Remove $ value
bo['revenue'] = bo['revenue'].str.replace('$', '')
bo['revenue'] = bo['revenue'].str.replace(',', '')

# %%
bo
# Out:
#              revenue       to_date
# date
# 07/21/2023  33017635   $33,017,635
# 07/22/2023  26248140   $59,265,775
# 07/23/2023  23189645   $82,455,420
# 07/24/2023  12671950   $95,127,370
# 07/25/2023  12073530  $107,200,900
# ...              ...           ...
# 03/17/2024     83460  $329,702,240
# 03/18/2024     38620  $329,740,860
# 03/19/2024     55355  $329,796,215
# 03/20/2024     39005  $329,835,220
# 03/21/2024     27320  $329,862,540
#
# [245 rows x 2 columns]

# %%
engagement['total'] = pd.to_numeric(engagement['total'], errors='coerce')
bo['revenue'] = pd.to_numeric(bo['revenue'], errors='coerce')

# %%
engagement_ts = engagement.copy()
bo_ts = bo.copy()

# %%
engagement_ts
# Out:
#             total
# date
# 2023-07-21   9694
# 2023-07-22  14647
# 2023-07-23  10657
# 2023-07-24   9220
# 2023-07-25   5166
# ...           ...
# 2024-03-17    683
# 2024-03-18    632
# 2024-03-19    474
# 2024-03-20    491
# 2024-03-21    732
#
# [245 rows x 1 columns]

# %%
bo_ts.head(45)
# Out:
#              revenue       to_date
# date
# 07/21/2023  33017635   $33,017,635
# 07/22/2023  26248140   $59,265,775
# 07/23/2023  23189645   $82,455,420
# 07/24/2023  12671950   $95,127,370
# 07/25/2023  12073530  $107,200,900
# 07/26/2023  10655845  $117,856,745
# 07/27/2023  10003685  $127,860,430
# 07/28/2023  13427475  $141,287,905
# 07/29/2023  18217115  $159,505,020
# 07/30/2023  15061040  $174,566,060
# 07/31/2023   6854460  $181,420,520
# 08/01/2023   6981975  $188,402,495
# 08/02/2023   5884010  $194,286,505
# 08/03/2023   5582115  $199,868,620
# 08/04/2023   8336045  $208,204,665
# 08/05/2023  11158205  $219,362,870
# 08/06/2023   9626790  $228,989,660
# 08/07/2023   4750015  $233,739,675
# 08/08/2023   4363530  $238,103,205
# 08/09/2023   3744420  $241,847,625
# 08/10/2023   3621850  $245,469,475
# 08/11/2023   5079435  $250,548,910
# 08/12/2023   7625585  $258,174,495
# 08/13/2023   6107950  $264,282,445
# 08/14/2023   2618585  $266,901,030
# 08/15/2023   3123675  $270,024,705
# 08/16/2023   2563220  $272,587,925
# 08/17/2023   2043810  $274,631,735
# 08/18/2023   3052220  $277,683,955
# 08/19/2023   4330355  $282,014,310
# 08/20/2023   3342935  $285,357,245
# 08/21/2023   1409670  $286,766,915
# 08/22/2023   1640710  $288,407,625
# 08/23/2023   1339220  $289,746,845
# 08/24/2023   1277415  $291,024,260
# 08/25/2023   2278125  $293,302,385
# 08/26/2023   3275360  $296,577,745
# 08/27/2023   2667265  $299,245,010
# 08/28/2023    899660  $300,144,670
# 08/29/2023   1112640  $301,257,310
# 08/30/2023    958450  $302,215,760
# 08/31/2023    815240  $303,031,000
# 09/01/2023   1375430  $304,406,430
# 09/02/2023   2063425  $306,469,855
# 09/03/2023   2318410  $308,788,265

# %%
# Combine your datasets into a single DataFrame 
combined_df = pd.concat([engagement_ts['total'], bo_ts['revenue']], axis=1)
combined_df.columns = ['total', 'revenue']

# %%
combined_df.head(60)
# Out:
#             total   revenue
# date
# 2023-07-21   9694  33017635
# 2023-07-22  14647  26248140
# 2023-07-23  10657  23189645
# 2023-07-24   9220  12671950
# 2023-07-25   5166  12073530
# 2023-07-26   3189  10655845
# 2023-07-27   2688  10003685
# 2023-07-28   2705  13427475
# 2023-07-29   2339  18217115
# 2023-07-30   3453  15061040
# 2023-07-31   2850   6854460
# 2023-08-01   2106   6981975
# 2023-08-02   1723   5884010
# 2023-08-03   1217   5582115
# 2023-08-04   1359   8336045
# 2023-08-05   1409  11158205
# 2023-08-06   1460   9626790
# 2023-08-07   2598   4750015
# 2023-08-08   1412   4363530
# 2023-08-09   1156   3744420
# 2023-08-10   1205   3621850
# 2023-08-11   1075   5079435
# 2023-08-12    800   7625585
# 2023-08-13    975   6107950
# 2023-08-14    914   2618585
# 2023-08-15    599   3123675
# 2023-08-16    654   2563220
# 2023-08-17    827   2043810
# 2023-08-18    559   3052220
# 2023-08-19    501   4330355
# 2023-08-20   1120   3342935
# 2023-08-21   1183   1409670
# 2023-08-22    565   1640710
# 2023-08-23    533   1339220
# 2023-08-24    566   1277415
# 2023-08-25   1393   2278125
# 2023-08-26   1107   3275360
# 2023-08-27    534   2667265
# 2023-08-28    861    899660
# 2023-08-29   1259   1112640
# 2023-08-30    753    958450
# 2023-08-31    912    815240
# 2023-09-01    473   1375430
# 2023-09-02    561   2063425
# 2023-09-03    595   2318410
# 2023-09-04    402   1900260
# 2023-09-05    343    566425
# 2023-09-06    320    475750
# 2023-09-07    391    406255
# 2023-09-08    316    805650
# 2023-09-09    263   1363015
# 2023-09-10    260    912095
# 2023-09-11    213    286180
# 2023-09-12    228    394100
# 2023-09-13    323    342230
# 2023-09-14    238    298890
# 2023-09-15    238    560985
# 2023-09-16    361    935245
# 2023-09-17    554    599265
# 2023-09-18    494    228365

# %%
#Making Data Stationary

#Differencing
#engagement_ts['total'] = engagement_ts['total'].diff()
#bo_ts['revenue'] = bo_ts['revenue'].diff()


#Taking Logarithm
#engagement_ts['total'] = np.log(engagement_ts['total'])
#bo_ts['revenue'] = bo_ts['revenue'].replace(-np.inf, np.nan)

# Dropping NA values after making it stationary
#engagement_ts.dropna(inplace=True)
#bo_ts.dropna(inplace=True)

# %%
#Checking Stationarity
from statsmodels.tsa.stattools import adfuller

def check_stationarity(series):
    result = adfuller(series, autolag='AIC')
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# Example usage
check_stationarity(engagement_ts['total'])
check_stationarity(bo_ts['revenue'])
# Out:
# ADF Statistic: -5.940475
# p-value: 0.000000
# Critical Values:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573
# ADF Statistic: -5.271550
# p-value: 0.000006
# Critical Values:
# 	1%: -3.459
# 	5%: -2.874
# 	10%: -2.574

# %%
fig, ax1 = plt.subplots(figsize=(20,10))

color = 'tab:blue'
ax1.set_xlabel('Timeline',fontsize=12,fontweight='bold')
ax1.set_ylabel('Social Media Engagement',color=color,fontsize=12,fontweight='bold')
ax1.plot(combined_df.index,combined_df['total'],color=color)
ax1.tick_params(axis='y',labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Revenue $',color=color,fontsize=12,fontweight='bold')
ax2.plot(combined_df.index, combined_df['revenue'],color=color)
ax2.tick_params(axis='y',labelcolor=color)

y_labels = ['{:,.0f}'.format(y) for y in plt.gca().get_yticks()]
plt.gca().set_yticklabels(y_labels)
plt.title('Oppenheimer: Social Media Engagement vs Box Office Revenue (185 days)',fontsize=12,fontweight='bold')

plt.grid(False)
plt.show()

# %%
correlation, _ = pearsonr(combined_df['total'], combined_df['revenue'])

# %%
print(f'Pearson correlation coefficient: {correlation}')
# Out:
# Pearson correlation coefficient: 0.2625480802149184

# %%
def cross_correlation(series1, series2, lag=0):
    return series1.corr(series2.shift(lag))

# Example usage:
lags = range(0, 7)  # Example lag values from 0 to 12
cross_corr_values = {}
for lag in lags:
    cross_corr_values[lag] = cross_correlation(combined_df['total'], combined_df['revenue'], lag)


max_pair = max(cross_corr_values.items(), key=lambda x: x[1])

#print(cross_corr_values.values())
#cross_corr_values = [cross_correlation(combined_df['total'], combined_df['revenue'], lag) for lag in lags]

print(f'Maximum Pearson correlation coefficient: {max_pair[1]}')
print(f'Lag associated with Maximum Pearson correlation coefficient: {max_pair[0]}')
# Plotting the cross-correlation values
import matplotlib
#matplotlib.use('TkAgg')  # Use TkAgg backend
import matplotlib.pyplot as plt

plt.figure(figsize=(24, 12))
plt.stem(lags, cross_corr_values.values(), use_line_collection=True)
plt.xlabel('Lag (Days)',fontsize=16,fontweight='bold')
plt.ylabel('Cross-correlation',fontsize=16,fontweight='bold',labelpad=20)
plt.title('Cross-correlation between Social Media Engagement and Box Office Revenue',fontsize=18,fontweight='bold')
plt.show()
# Out:
# Maximum Pearson correlation coefficient: 0.2625480802149187
# Lag associated with Maximum Pearson correlation coefficient: 0

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests

# Combine your datasets into a single DataFrame for the Granger causality test
combined_df = pd.concat([engagement_ts['total'], bo_ts['revenue']], axis=1)
combined_df.columns = ['total', 'revenue']

# Perform the Granger causality test
# The maxlag parameter is the maximum lag to test for, and the test 'ssr_chi2test' is one of the possible tests
granger_test_results = grangercausalitytests(combined_df, maxlag=10, verbose=True)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.0315  , p=0.0458  , df_denom=241, df_num=1
# ssr based chi2 test:   chi2=4.0817  , p=0.0433  , df=1
# likelihood ratio test: chi2=4.0479  , p=0.0442  , df=1
# parameter F test:         F=4.0315  , p=0.0458  , df_denom=241, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8913  , p=0.4115  , df_denom=238, df_num=2
# ssr based chi2 test:   chi2=1.8201  , p=0.4025  , df=2
# likelihood ratio test: chi2=1.8134  , p=0.4039  , df=2
# parameter F test:         F=0.8913  , p=0.4115  , df_denom=238, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2572  , p=0.8562  , df_denom=235, df_num=3
# ssr based chi2 test:   chi2=0.7944  , p=0.8508  , df=3
# likelihood ratio test: chi2=0.7931  , p=0.8511  , df=3
# parameter F test:         F=0.2572  , p=0.8562  , df_denom=235, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0865  , p=0.9866  , df_denom=232, df_num=4
# ssr based chi2 test:   chi2=0.3595  , p=0.9857  , df=4
# likelihood ratio test: chi2=0.3593  , p=0.9857  , df=4
# parameter F test:         F=0.0865  , p=0.9866  , df_denom=232, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.0505  , p=0.9984  , df_denom=229, df_num=5
# ssr based chi2 test:   chi2=0.2645  , p=0.9983  , df=5
# likelihood ratio test: chi2=0.2644  , p=0.9983  , df=5
# parameter F test:         F=0.0505  , p=0.9984  , df_denom=229, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.0601  , p=0.9991  , df_denom=226, df_num=6
# ssr based chi2 test:   chi2=0.3810  , p=0.9990  , df=6
# likelihood ratio test: chi2=0.3807  , p=0.9990  , df=6
# parameter F test:         F=0.0601  , p=0.9991  , df_denom=226, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.0640  , p=0.9996  , df_denom=223, df_num=7
# ssr based chi2 test:   chi2=0.4783  , p=0.9995  , df=7
# likelihood ratio test: chi2=0.4779  , p=0.9995  , df=7
# parameter F test:         F=0.0640  , p=0.9996  , df_denom=223, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.0509  , p=0.9999  , df_denom=220, df_num=8
# ssr based chi2 test:   chi2=0.4389  , p=0.9999  , df=8
# likelihood ratio test: chi2=0.4384  , p=0.9999  , df=8
# parameter F test:         F=0.0509  , p=0.9999  , df_denom=220, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.0808  , p=0.9998  , df_denom=217, df_num=9
# ssr based chi2 test:   chi2=0.7904  , p=0.9998  , df=9
# likelihood ratio test: chi2=0.7891  , p=0.9998  , df=9
# parameter F test:         F=0.0808  , p=0.9998  , df_denom=217, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.0266  , p=1.0000  , df_denom=214, df_num=10
# ssr based chi2 test:   chi2=0.2923  , p=1.0000  , df=10
# likelihood ratio test: chi2=0.2921  , p=1.0000  , df=10
# parameter F test:         F=0.0266  , p=1.0000  , df_denom=214, df_num=10

# %%
#Linear Regression Fit
reg_engagement
# Out:
#                       0   1        2          3         4                 5  \
# days        Online News  QQ  YouTube  Broadcast  Facebook  Legacy Instagram
# 07/21/2023         3727   0       98          0         0                 0
# 07/22/2023         1757   0      108          0         0                 0
# 07/23/2023         1776   0       96          0         0                 0
# 07/24/2023         3394   0       99          0         4                 0
# ...                 ...  ..      ...        ...       ...               ...
# 01/17/2024         1264   0       21          0         0                 0
# 01/18/2024         1992   0       16          0         0                 0
# 01/19/2024          636   0       10          0         0                 0
# 01/20/2024          367   0        1          0         0                 0
# 01/21/2024          834   0       12          0         0                 0
#
#                  6          7         8      9      10               11  \
# days        Tumblr  Instagram  LinkedIn  Blogs  Forums  Facebook Public
# 07/21/2023    4349          1         0    235     320              210
# 07/22/2023    6020          0         0    114     452               72
# 07/23/2023    6746          1         0    150     592               56
# 07/24/2023    6423          0         0    211     399              101
# ...            ...        ...       ...    ...     ...              ...
# 01/17/2024     181          0         0     20      18                2
# 01/18/2024     147          0         0     27      28               13
# 01/19/2024     177          1         0     26      22               12
# 01/20/2024     256          0         0     10      12                3
# 01/21/2024     337          1         0     16      24                2
#
#                12  13      14      15     16
# days            X  VK  Review  Reddit  4Chan
# 07/21/2023  14482   0      24     875      0
# 07/22/2023  24852   0      28    1356      0
# 07/23/2023  15922   0      16    1662      0
# 07/24/2023   7442   0      24    1499      0
# ...           ...  ..     ...     ...    ...
# 01/17/2024    231   0       0      83      0
# 01/18/2024    588   0       1     299      0
# 01/19/2024    189   0       1     103      0
# 01/20/2024     93   0       3      54      0
# 01/21/2024     91   0       3      54      0
#
# [186 rows x 17 columns]

# %%
#Make first row as Columns
reg_engagement.columns = reg_engagement.iloc[0]

# %%
#Drop first row
reg_engagement = reg_engagement.drop(reg_engagement.index[0])

# %%
#Drop Columns (Content Sources where all values are 0)
reg_engagement = reg_engagement.loc[:, (reg_engagement != 0).any(axis=0)]

# %%
reg_engagement = reg_engagement.rename(columns={'days': 'date'})

# %%
reg_engagement
# Out:
# days       Online News YouTube Facebook Tumblr Instagram Blogs Forums  \
# 07/21/2023        3727      98        0   4349         1   235    320
# 07/22/2023        1757     108        0   6020         0   114    452
# 07/23/2023        1776      96        0   6746         1   150    592
# 07/24/2023        3394      99        4   6423         0   211    399
# 07/25/2023        2417     114        1   8398         0   169    259
# ...                ...     ...      ...    ...       ...   ...    ...
# 01/17/2024        1264      21        0    181         0    20     18
# 01/18/2024        1992      16        0    147         0    27     28
# 01/19/2024         636      10        0    177         1    26     22
# 01/20/2024         367       1        0    256         0    10     12
# 01/21/2024         834      12        0    337         1    16     24
#
# days       Facebook Public      X Review Reddit
# 07/21/2023             210  14482     24    875
# 07/22/2023              72  24852     28   1356
# 07/23/2023              56  15922     16   1662
# 07/24/2023             101   7442     24   1499
# 07/25/2023              73   4258     24   1647
# ...                    ...    ...    ...    ...
# 01/17/2024               2    231      0     83
# 01/18/2024              13    588      1    299
# 01/19/2024              12    189      1    103
# 01/20/2024               3     93      3     54
# 01/21/2024               2     91      3     54
#
# [185 rows x 11 columns]

# %%
shift = -1 #Based on Lag

# %%
bo_series = bo['revenue']

# %%
bo_series
# Out:
# date
# 07/21/2023    70503178
# 07/22/2023    47812356
# 07/23/2023    43706510
# 07/24/2023    26105167
# 07/25/2023    26003569
#                 ...
# 01/17/2024          36
# 01/18/2024         145
# 01/19/2024         791
# 01/20/2024         574
# 01/21/2024         655
# Name: revenue, Length: 185, dtype: int64

# %%
bo_series_shifted = bo_series.shift(shift)

# %%
bo_series_shifted = bo_series_shifted[:shift]

# %%
bo_series_shifted
# Out:
# date
# 07/21/2023    47812356.0
# 07/22/2023    43706510.0
# 07/23/2023    26105167.0
# 07/24/2023    26003569.0
# 07/25/2023    23034051.0
#                  ...
# 01/16/2024          36.0
# 01/17/2024         145.0
# 01/18/2024         791.0
# 01/19/2024         574.0
# 01/20/2024         655.0
# Name: revenue, Length: 184, dtype: float64

# %%
reg_engagement = reg_engagement.iloc[:shift, :]

# %%
reg_engagement
# Out:
# days       Online News YouTube Facebook Tumblr Instagram Blogs Forums  \
# 07/21/2023        3727      98        0   4349         1   235    320
# 07/22/2023        1757     108        0   6020         0   114    452
# 07/23/2023        1776      96        0   6746         1   150    592
# 07/24/2023        3394      99        4   6423         0   211    399
# 07/25/2023        2417     114        1   8398         0   169    259
# ...                ...     ...      ...    ...       ...   ...    ...
# 01/16/2024         756       4        0    232         1    23     22
# 01/17/2024        1264      21        0    181         0    20     18
# 01/18/2024        1992      16        0    147         0    27     28
# 01/19/2024         636      10        0    177         1    26     22
# 01/20/2024         367       1        0    256         0    10     12
#
# days       Facebook Public      X Review Reddit
# 07/21/2023             210  14482     24    875
# 07/22/2023              72  24852     28   1356
# 07/23/2023              56  15922     16   1662
# 07/24/2023             101   7442     24   1499
# 07/25/2023              73   4258     24   1647
# ...                    ...    ...    ...    ...
# 01/16/2024               3    111      1     35
# 01/17/2024               2    231      0     83
# 01/18/2024              13    588      1    299
# 01/19/2024              12    189      1    103
# 01/20/2024               3     93      3     54
#
# [184 rows x 11 columns]

# %%
reg_engagement = reg_engagement.astype(int)

# %%
reg_engagement
# Out:
# days        Online News  YouTube  Facebook  Tumblr  Instagram  Blogs  Forums  \
# 07/21/2023         3727       98         0    4349          1    235     320
# 07/22/2023         1757      108         0    6020          0    114     452
# 07/23/2023         1776       96         0    6746          1    150     592
# 07/24/2023         3394       99         4    6423          0    211     399
# 07/25/2023         2417      114         1    8398          0    169     259
# ...                 ...      ...       ...     ...        ...    ...     ...
# 01/16/2024          756        4         0     232          1     23      22
# 01/17/2024         1264       21         0     181          0     20      18
# 01/18/2024         1992       16         0     147          0     27      28
# 01/19/2024          636       10         0     177          1     26      22
# 01/20/2024          367        1         0     256          0     10      12
#
# days        Facebook Public      X  Review  Reddit
# 07/21/2023              210  14482      24     875
# 07/22/2023               72  24852      28    1356
# 07/23/2023               56  15922      16    1662
# 07/24/2023              101   7442      24    1499
# 07/25/2023               73   4258      24    1647
# ...                     ...    ...     ...     ...
# 01/16/2024                3    111       1      35
# 01/17/2024                2    231       0      83
# 01/18/2024               13    588       1     299
# 01/19/2024               12    189       1     103
# 01/20/2024                3     93       3      54
#
# [184 rows x 11 columns]

# %%
bo_series_shifted
# Out:
# date
# 07/21/2023    47812356.0
# 07/22/2023    43706510.0
# 07/23/2023    26105167.0
# 07/24/2023    26003569.0
# 07/25/2023    23034051.0
#                  ...
# 01/16/2024          36.0
# 01/17/2024         145.0
# 01/18/2024         791.0
# 01/19/2024         574.0
# 01/20/2024         655.0
# Name: revenue, Length: 184, dtype: float64

# %%
# Prepare the features (X) and the target (y)
X = reg_engagement  # 'Reg Engagement' df as features
y = bo_series_shifted  # 'Revenue' series

# Reset index if necessary
X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Add a constant to the model (for the intercept)
X_scaled_with_const = sm.add_constant(X_scaled)

# Fit the OLS model
model = sm.OLS(y, X_scaled_with_const).fit()

# Get the regression report
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     150.7
# Date:                Wed, 17 Apr 2024   Prob (F-statistic):           3.60e-82
# Time:                        17:10:38   Log-Likelihood:                -2957.8
# No. Observations:                 184   AIC:                             5940.
# Df Residuals:                     172   BIC:                             5978.
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3.075e+06   1.77e+05     17.402      0.000    2.73e+06    3.42e+06
# Online News     -1.212e+06   2.71e+05     -4.476      0.000   -1.75e+06   -6.78e+05
# YouTube          1.074e+06   6.06e+05      1.773      0.078   -1.22e+05    2.27e+06
# Facebook        -7.177e+05   2.21e+05     -3.252      0.001   -1.15e+06   -2.82e+05
# Tumblr           3.177e+06   6.76e+05      4.703      0.000    1.84e+06    4.51e+06
# Instagram         2.34e+05   2.02e+05      1.156      0.249   -1.66e+05    6.34e+05
# Blogs             1.23e+06   6.22e+05      1.977      0.050    2106.756    2.46e+06
# Forums          -9.312e+04   4.97e+05     -0.187      0.852   -1.07e+06    8.88e+05
# Facebook Public  1.535e+06   3.98e+05      3.853      0.000    7.49e+05    2.32e+06
# X                1.175e+06   3.48e+05      3.375      0.001    4.88e+05    1.86e+06
# Review           1.605e+06    2.9e+05      5.527      0.000    1.03e+06    2.18e+06
# Reddit          -6.312e+05   6.14e+05     -1.028      0.305   -1.84e+06     5.8e+05
# ==============================================================================
# Omnibus:                       84.863   Durbin-Watson:                   1.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1106.180
# Skew:                           1.321   Prob(JB):                    6.25e-241
# Kurtosis:                      14.718   Cond. No.                         12.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
# Extract the coefficients (excluding the intercept) and sort them by their absolute values
coefficients = model.params.drop('const').abs().sort_values(ascending=False)

# Print the sorted coefficients to identify the top contributing features
print("\nTop Contributing Features:")
print(coefficients)
# Out:
# Top Contributing Features:
# Tumblr             3.176914e+06
# Review             1.604520e+06
# Facebook Public    1.535456e+06
# Blogs              1.230184e+06
# Online News        1.212249e+06
# X                  1.175138e+06
# YouTube            1.073992e+06
# Facebook           7.176899e+05
# Reddit             6.312422e+05
# Instagram          2.339811e+05
# Forums             9.312340e+04
# dtype: float64
